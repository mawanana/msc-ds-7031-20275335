# %%
import pandas as pd
from sklearn.utils import resample

# Load your dataset
df = pd.read_csv('Sample.csv')

from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Initialize a list to store the model accuracies
accuracies = []

# Define the number of Bootstrapping iterations
num_iterations = 100

# Initialize empty lists to store training and test datasets
training_datasets = []
test_datasets = []

# Perform Bootstrapping
for _ in range(num_iterations):
    # Randomly sample the data with replacement
    bootstrap_sample = data.sample(frac=1, replace=True)
    
    # Split the data into training and test sets (e.g., 80% for training and 20% for testing)
    train_set = bootstrap_sample.sample(frac=0.8)
    test_set = bootstrap_sample.drop(train_set.index)
    
    # Append the training and test sets to the respective lists
    training_datasets.append(train_set)
    test_datasets.append(test_set)

# Now, you have created the training_datasets and test_datasets

# Access the first training dataset
first_training_dataset = training_datasets[0]

# Access the first test dataset
first_test_dataset = test_datasets[0]

# Define features and target variable
X_train = first_training_dataset.drop(columns=['Index', 'Qty', 'DateofWork'])
y_train = first_training_dataset['Qty']
X_test = first_test_dataset.drop(columns=['Index', 'Qty', 'DateofWork'])
y_test = first_test_dataset['Qty']

# Initialize and train the Decision Tree model
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)

# Make predictions on the test data
y_pred = clf.predict(X_test)

# Calculate accuracy and append it to the accuracies list
accuracy = accuracy_score(y_test, y_pred)
accuracies.append(accuracy)

# Print the accuracy for this model on the first test dataset
print(f'Accuracy on the first test dataset: {accuracy}')
# Out:
# Bootstrapped Training Dataset 1:
#          Index  EmpCode EState Division CropType Field  Area (Ha)  \
# 21038    21039    68175    EST       HO        T   FW4        0.5
# 293653  293654   537017    EST       MD        T  C4EM        1.5
# 265761  265762   482679    EST       MD        T  C4EV        1.0
# 491875  491876   569741    EST       UD        T   GEN        3.0
# 305925  305926   569135    EST       MD        T    4E        0.5
#
#         NumberOfTree Type Work  Workdayfraction  Qty  ExtraKilos  DateofWork
# 21038           5855    C  PLK                1   62         0.0  2013-02-28
# 293653         19425    C  ABS                1   49         6.0  2015-03-03
# 265761         13500    C  ABS                1   78        14.0  2013-09-25
# 491875         17631    R  LLO                1   83         0.0  2012-09-05
# 305925          6500    R  ABS                1   48        14.0  2012-04-20
#
# Bootstrapped Test Dataset 1:
# ...

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# Initialize a list to store the model accuracies
accuracies = []

# Let's use the first Bootstrapped dataset for this example
# Access the first training dataset
first_training_dataset = training_datasets[0]

# Access the first test dataset
first_test_dataset = test_datasets[0]

# Define features and target variable
X_train = first_training_dataset.drop(columns=['Index', 'Qty', 'DateofWork'])
y_train = first_training_dataset['Qty']
X_test = first_test_dataset.drop(columns=['Index', 'Qty', 'DateofWork'])
y_test = first_test_dataset['Qty']

# Initialize and train the Decision Tree model
clf = DecisionTreeClassifier()
clf.fit(X_train, y_train)

# Make predictions on the test data
y_pred = clf.predict(X_test)

# Calculate accuracy and append it to the accuracies list
accuracy = accuracy_score(y_test, y_pred)
accuracies.append(accuracy)

# Print the accuracy for this model on the first test dataset
print(f'Accuracy on the first test dataset: {accuracy}')

# Repeat the above code for different Bootstrapped datasets to get a distribution of accuracies
# You can use a loop to iterate through training and test datasets and train multiple models
# to evaluate the stability of the Decision Tree algorithm on Bootstrapped data

# Finally, you can analyze the distribution of accuracies to assess model performance
# and the variance in performance due to Bootstrapping
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 9
#       5 accuracies = []
#       7 # Let's use the first Bootstrapped dataset for this example
#       8 # Access the first training dataset
# ----> 9 first_training_dataset = training_datasets[0]
#      11 # Access the first test dataset
#      12 first_test_dataset = test_datasets[0]
#
# NameError: name 'training_datasets' is not defined
